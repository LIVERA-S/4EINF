# %% [markdown]
# <a href="https://colab.research.google.com/github/LIVERA-S/21-22_INFORMATICA_LIVERA-4EINF/blob/main/Pandas_Esercizi%20(05-11-2021).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# **1. caricare i dati in un dataframe e studiare le informazioni inserite per capire di che cosa si tratta**

# %%
df= pd.read_csv('https://raw.githubusercontent.com/CappuCitti/Python-appunti-ed-esercizi/main/Pandas/Data/uffici_postali_milano.csv')
df
# Out:
#                       Indirizzo  ...                                Location
# 0     BASTIONI DI PORTA VOLTA 7  ...   (45.47960100000006;9.182151000000033)
# 1   CORSO DI PORTA VIGENTINA 35  ...   (45.45253800000006;9.196519500000022)
# 2                CORSO ITALI 16  ...   (45.45789300000007;9.187470000000076)
# 3             CORSO SEMPIONE 94  ...    (45.48654000000005;9.15850800000004)
# 4              CORSO VENEZIA 42  ...   (45.47186100000005;9.202702500000044)
# ..                          ...  ...                                     ...
# 77              VIALE GORIZIA 6  ...  (45.454518000000064;9.173155500000064)
# 78       VIALE MONTE CENERI SNC  ...   (45.49156751800007;9.153591732000052)
# 79          VIALE SABOTINO 21/A  ...  (45.451017000000036;9.200173500000062)
# 80       VIALE SAN GIMIGNANO 10  ...  (45.455868000000066;9.136525500000062)
# 81               VIALE ZARA 131  ...   (45.50019300000008;9.196686000000057)
#
# [82 rows x 10 columns]

# %% [markdown]
# **Scrivere poi le istruzioni per effettuare le seguenti operazioni:**

# %% [markdown]
# # **operazioni sulle colonne**

# %% [markdown]
# **2. visualizzare solo la prima colonna**

# %%
#df[['Indirizzo']]
#df.iloc[:,0]
df.iloc[:,[0]]
# Out:
#                       Indirizzo
# 0     BASTIONI DI PORTA VOLTA 7
# 1   CORSO DI PORTA VIGENTINA 35
# 2                CORSO ITALI 16
# 3             CORSO SEMPIONE 94
# 4              CORSO VENEZIA 42
# ..                          ...
# 77              VIALE GORIZIA 6
# 78       VIALE MONTE CENERI SNC
# 79          VIALE SABOTINO 21/A
# 80       VIALE SAN GIMIGNANO 10
# 81               VIALE ZARA 131
#
# [82 rows x 1 columns]

# %%
df[df.columns[0]]
# Out:
# 0       BASTIONI DI PORTA VOLTA 7
# 1     CORSO DI PORTA VIGENTINA 35
# 2                  CORSO ITALI 16
# 3               CORSO SEMPIONE 94
# 4                CORSO VENEZIA 42
#                  ...
# 77                VIALE GORIZIA 6
# 78         VIALE MONTE CENERI SNC
# 79            VIALE SABOTINO 21/A
# 80         VIALE SAN GIMIGNANO 10
# 81                 VIALE ZARA 131
# Name: Indirizzo, Length: 82, dtype: object

# %% [markdown]
# **3. visualizzare solo l'ultima colonna**

# %%
df[['Location']]
# Out:
#                                   Location
# 0    (45.47960100000006;9.182151000000033)
# 1    (45.45253800000006;9.196519500000022)
# 2    (45.45789300000007;9.187470000000076)
# 3     (45.48654000000005;9.15850800000004)
# 4    (45.47186100000005;9.202702500000044)
# ..                                     ...
# 77  (45.454518000000064;9.173155500000064)
# 78   (45.49156751800007;9.153591732000052)
# 79  (45.451017000000036;9.200173500000062)
# 80  (45.455868000000066;9.136525500000062)
# 81   (45.50019300000008;9.196686000000057)
#
# [82 rows x 1 columns]

# %%
df.iloc[:,-1:]
#df.iloc[:,[-]1]
# Out:
#                                   Location
# 0    (45.47960100000006;9.182151000000033)
# 1    (45.45253800000006;9.196519500000022)
# 2    (45.45789300000007;9.187470000000076)
# 3     (45.48654000000005;9.15850800000004)
# 4    (45.47186100000005;9.202702500000044)
# ..                                     ...
# 77  (45.454518000000064;9.173155500000064)
# 78   (45.49156751800007;9.153591732000052)
# 79  (45.451017000000036;9.200173500000062)
# 80  (45.455868000000066;9.136525500000062)
# 81   (45.50019300000008;9.196686000000057)
#
# [82 rows x 1 columns]

# %%
#df[[df.columns[-1]]]

# %% [markdown]
# **4. visualizzare le colonne dalle terza alla quinta**

# %%
df.iloc[:, 2:6]
# Out:
#             Fax    CAP  MUNICIPIO  ID_NIL
# 0   02-29002004  20121          1       2
# 1   02-58319779  20122          1       5
# 2   02-86454450  20122          1       1
# 3           NaN  20154          8      69
# 4    02-7837251  20121          1       4
# ..          ...    ...        ...     ...
# 77   02-8373830  20144          6      44
# 78  02-32671947  20155          8      71
# 79  02-58457947  20135          5      27
# 80  02-41411347  20146          6      52
# 81  02-69911147  20159          9      12
#
# [82 rows x 4 columns]

# %% [markdown]
# **5. visualizzare la terza e la sesta colonna**

# %%
df.iloc[0:,[3,6]]
# Out:
#       CAP                                  NIL
# 0   20121                                BRERA
# 1   20122     PORTA VIGENTINA - PORTA LODOVICA
# 2   20122                                DUOMO
# 3   20154                                SARPI
# 4   20121                            GUASTALLA
# ..    ...                                  ...
# 77  20144           PORTA TICINESE - CONCHETTA
# 78  20155  VILLAPIZZONE - CAGNOLA - BOLDINASCO
# 79  20135                           PTA ROMANA
# 80  20146                           BANDE NERE
# 81  20159              MACIACHINI - MAGGIOLINA
#
# [82 rows x 2 columns]

# %% [markdown]
# **6. visualizzare la colonna dell'indirizzo e del municipio**

# %%
df[['Indirizzo','MUNICIPIO']]
# Out:
#                       Indirizzo  MUNICIPIO
# 0     BASTIONI DI PORTA VOLTA 7          1
# 1   CORSO DI PORTA VIGENTINA 35          1
# 2                CORSO ITALI 16          1
# 3             CORSO SEMPIONE 94          8
# 4              CORSO VENEZIA 42          1
# ..                          ...        ...
# 77              VIALE GORIZIA 6          6
# 78       VIALE MONTE CENERI SNC          8
# 79          VIALE SABOTINO 21/A          5
# 80       VIALE SAN GIMIGNANO 10          6
# 81               VIALE ZARA 131          9
#
# [82 rows x 2 columns]

# %% [markdown]
# # **Operazioni sulle righe**

# %% [markdown]
# **7. visualizzare la prima riga**

# %%
df.head(1)
# Out:
#                    Indirizzo  ...                               Location
# 0  BASTIONI DI PORTA VOLTA 7  ...  (45.47960100000006;9.182151000000033)
#
# [1 rows x 10 columns]

# %% [markdown]
# **8. visualizzare l'ultima riga**

# %%
df.tail(1)
#df[-1:]
# Out:
#          Indirizzo  ...                               Location
# 81  VIALE ZARA 131  ...  (45.50019300000008;9.196686000000057)
#
# [1 rows x 10 columns]

# %% [markdown]
# **9. visualizzare la riga centrale**

# %%
df.iloc[[len(df)//2]]
# Out:
#                      Indirizzo  ...                               Location
# 41  VIA GIUSEPPE RIPAMONTI 167  ...  (45.43522200000007;9.201118500000064)
#
# [1 rows x 10 columns]

# %%
len(df)
# Out:
# 82

# %%
if len(df)%2 == 0:
  print(df.iloc[[len(df)//2]])
  print(df.iloc[[(len(df)//2)+1]])
else:
  print(df.iloc[[len(df)//2]])
# Out:
#                      Indirizzo  ...                               Location
# 41  VIA GIUSEPPE RIPAMONTI 167  ...  (45.43522200000007;9.201118500000064)
#
# [1 rows x 10 columns]
#                     Indirizzo  ...                               Location
# 42  VIA GIUSEPPE UNGARETTI 12  ...  (45.51535800000005;9.142164000000037)
#
# [1 rows x 10 columns]

# %% [markdown]
# **10. visualizzare le righe 3, 4 e 12**

# %%
df.iloc[[3,4,12]]
# Out:
#              Indirizzo  ...                               Location
# 3    CORSO SEMPIONE 94  ...   (45.48654000000005;9.15850800000004)
# 4     CORSO VENEZIA 42  ...  (45.47186100000005;9.202702500000044)
# 12  VIA APPENNINI 77/A  ...  (45.50207400000005;9.104292000000044)
#
# [3 rows x 10 columns]

# %% [markdown]
# **11. visualizzare le righe dalla decima alla quindicesima**

# %%
df[10:16]
# Out:
#                        Indirizzo  ...                                Location
# 10  VIA ALFREDO CAPPELLINI 17/19  ...   (45.48195000000004;9.201735000000042)
# 11        VIA ANDREA VOCHIERI 12  ...   (45.51414300000005;9.168682500000045)
# 12            VIA APPENNINI 77/A  ...   (45.50207400000005;9.104292000000044)
# 13                 VIA ARQUA' 14  ...    (45.49287600000008;9.22771350000005)
# 14        VIA BENOZZO GOZZOLI 51  ...   (45.45560700000004;9.090990000000033)
# 15             VIA BOVISASCA 173  ...  (45.519456269000045;9.152854782000077)
#
# [6 rows x 10 columns]

# %% [markdown]
# # **operazioni sulle righe e sulle colonne**

# %% [markdown]
# **12. visualizzare la colonna indirizzo e NIL delle righe dalla decima alla quindicesima**

# %%
df[10:16][['Indirizzo','NIL']]
# Out:
#                        Indirizzo                                                NIL
# 10  VIA ALFREDO CAPPELLINI 17/19                   STAZIONE CENTRALE - PONTE SEVESO
# 11        VIA ANDREA VOCHIERI 12                                             AFFORI
# 12            VIA APPENNINI 77/A  Q.RE GALLARATESE - Q.RE SAN LEONARDO - LAMPUGNANO
# 13                 VIA ARQUA' 14                          LORETO - CASORETTO - NOLO
# 14        VIA BENOZZO GOZZOLI 51           BAGGIO - Q.RE DEGLI OLMI - Q.RE VALSESIA
# 15             VIA BOVISASCA 173                                          BOVISASCA

# %% [markdown]
# **13. visualizzare le colonne telefono e fax delle righe 3, 5 e 12**

# %%
df.iloc[[3,5,12]][["Telefono", "Fax"]]
# Out:
#        Telefono          Fax
# 3           NaN          NaN
# 5   02-47714011  02-47714047
# 12   02-3535414   02-3538072

# %% [markdown]
# **14. visualizzare le colonne dalla 2 alla 6 delle righe dalla 3 alla 10**

# %%
df[3:11].iloc[0: , 1:7]
# Out:
#        Telefono          Fax  ...  ID_NIL                               NIL
# 3           NaN          NaN  ...      69                             SARPI
# 4   02-76023056   02-7837251  ...       4                         GUASTALLA
# 5   02-47714011  02-47714047  ...      49                       GIAMBELLINO
# 6   02-42255211  02-42255247  ...      49                       GIAMBELLINO
# 7     02-325774   02-3271232  ...      66                              QT 8
# 8   02-37790911  02-37790947  ...      78                            FARINI
# 9    02-2665192  02-26680123  ...      22                      CITTA' STUDI
# 10   02-6773311  02-67733147  ...      10  STAZIONE CENTRALE - PONTE SEVESO
#
# [8 rows x 6 columns]

# %% [markdown]
# # **Ricerca di informazioni**

# %% [markdown]
# **15. visualizzare il numero di telefono dell'ufficio di piazza Napoli**

# %%
df[df['Indirizzo'].str.contains("PIAZZA NAPOLI")]
# Out:
#           Indirizzo  ...                               Location
# 6  PIAZZA NAPOLI 38  ...  (45.45247500000005;9.152788500000042)
#
# [1 rows x 10 columns]

# %% [markdown]
# **16. visualizzare l'indirizzo e il numero di telefono degli uffici postali di Niguarda**

# %%
df[df['NIL'].str.contains("NIGUARDA")][['Indirizzo','Telefono']]
# Out:
#                  Indirizzo     Telefono
# 60            VIA PONALE 6  02-66100185
# 76  VIALE GIOVANNI SUZZANI   02-6470400

# %% [markdown]
# **17. visualizzare l'indirizzo e il numero di telefono degli uffici postali dei municipi 1, 2 e 3**

# %%
#df[df['MUNICIPIO'].isin([1,2,3])][['Indirizzo','Telefono','MUNICIPIO' ]].sort_values('Indirizzo',  ascending=False)
df[df['MUNICIPIO'].isin(['1','2','3'])][['Indirizzo','Telefono','MUNICIPIO' ]].sort_values('Indirizzo',  ascending=False)
# Out:
#                        Indirizzo     Telefono  MUNICIPIO
# 75     VIALE EVARISTO STEFINI 12  02-67361911          2
# 73         VIALE ANDREA DORIA 48   02-2047169          3
# 72                   VIA VIGNA 6  02-86396711          1
# 71       VIA SCIPIONE PIATTOLI 6  02-26112432          2
# 69             VIA SANTA SOFIA 8  02-58318572          1
# 68         VIA SAN SIMPLICIANO 5  02-86396811          1
# 67             VIA SAN MAMETE 16   02-2566786          2
# 66                VIA SAMBUCO 15  02-89405932          1
# 64        VIA ROSOLINO PILO 19/A   02-2046789          3
# 59                VIA PINDARO 29          NaN          2
# 55                 VIA ORTICA 19  02-70061332          3
# 51                VIA MONDOVI' 2  02-26300993          2
# 49       VIA MAZZINI GIUSEPPE 15  02-86396911          1
# 46      VIA LUIGI VARANINI 26/28  02-28181611          2
# 40        VIA GIUSEPPE PECCHIO 1          NaN          3
# 38        VIA GIOSUE' CARDUCCI 7  02-85917111          1
# 30      VIA FESTA DEL PERDONO 10  02-58207833          1
# 27                 VIA DURAZZO 5  02-21040511          3
# 26          VIA DELLA MOSCOVA 30          NaN          1
# 25              VIA DELL'ORSO 11  02-80277311          1
# 22                VIA CORDUSIO 4  02-72482126          1
# 21           VIA COMUNE ANTICO 1  02-67070525          2
# 16                VIA BRONZINO 7  02-29527423          3
# 13                 VIA ARQUA' 14  02-26141687          2
# 10  VIA ALFREDO CAPPELLINI 17/19   02-6773311          2
# 9                  VIA ADELCHI 2   02-2665192          3
# 4               CORSO VENEZIA 42  02-76023056          1
# 2                 CORSO ITALI 16    02-804336          1
# 1    CORSO DI PORTA VIGENTINA 35  02-58320771          1
# 0      BASTIONI DI PORTA VOLTA 7   02-6572655          1

# %% [markdown]
# **18. visualizzare gli uffici di cui non si conosce il numero di telefono o il fax**

# %%
df[df['Telefono'].isnull()]
# Out:
#                   Indirizzo  ...                                Location
# 3         CORSO SEMPIONE 94  ...    (45.48654000000005;9.15850800000004)
# 26     VIA DELLA MOSCOVA 30  ...  (45.476856000000055;9.189607500000022)
# 31  VIA FILIPPO SASSETTI 27  ...   (45.48825900000003;9.193140000000028)
# 40   VIA GIUSEPPE PECCHIO 1  ...   (45.48473100000007;9.215860500000076)
# 59           VIA PINDARO 29  ...   (45.51700500000004;9.229959000000065)
#
# [5 rows x 10 columns]

# %%
df[df.isna().any(axis = 1)]

# %% [markdown]
# # **Raggruppamento**

# %% [markdown]
# **19. visualizzare il numero di uffici per ogni Nucleo di Identità Locale (NIL)**

# %%
#df.groupby(df['NIL']).count()
df1 = df.groupby(df['NIL']).count()[['Indirizzo']].rename(columns={"Indirizzo":"UFFICI"})
df1
#.rename(columns={"Indirizzo":"UFFICI"}) per cambiare il nome della colonna
#df.groupby('NIL').size()
# Out:
#                                                     UFFICI
# NIL
# ADRIANO                                                  1
# AFFORI                                                   2
# BAGGIO - Q.RE DEGLI OLMI - Q.RE VALSESIA                 2
# BANDE NERE                                               1
# BOVISASCA                                                1
# BRERA                                                    4
# BRUZZANO                                                 1
# BUENOS AIRES - PORTA VENEZIA - PORTA MONFORTE            4
# CIMIANO - ROTTOLE - Q.RE FELTRE                          1
# CITTA' STUDI                                             1
# CORSICA                                                  1
# DE ANGELI - MONTE ROSA                                   1
# DERGANO                                                  1
# DUOMO                                                    7
# FARINI                                                   1
# FORZE ARMATE                                             2
# GIAMBELLINO                                              3
# GORLA - PRECOTTO                                         1
# GRATOSOGLIO - Q.RE MISSAGLIA - Q.RE TERRAZZE             1
# GRECO - SEGNANO                                          1
# GUASTALLA                                                1
# ISOLA                                                    3
# LAMBRATE - ORTICA                                        1
# LODI - CORVETTO                                          1
# LORETO - CASORETTO - NOLO                                2
# MACIACHINI - MAGGIOLINA                                  2
# MONCUCCO - SAN CRISTOFORO                                1
# MONLUE' - PONTE LAMBRO                                   1
# NIGUARDA - CA' GRANDA - PRATO CENTENARO - Q.RE ...       2
# PADOVA - TURRO - CRESCENZAGO                             2
# PAGANO                                                   1
# PORTA GARIBALDI - PORTA NUOVA                            1
# PORTA GENOVA                                             1
# PORTA MAGENTA                                            1
# PORTA TICINESE - CONCA DEL NAVIGLIO                      1
# PORTA TICINESE - CONCHETTA                               1
# PORTA VIGENTINA - PORTA LODOVICA                         1
# PTA ROMANA                                               1
# Q.RE GALLARATESE - Q.RE SAN LEONARDO - LAMPUGNANO        2
# QT 8                                                     1
# QUARTO OGGIARO - VIALBA - MUSOCCO                        2
# QUINTO ROMANO                                            1
# ROGOREDO - SANTA GIULIA                                  1
# RONCHETTO SUL NAVIGLIO - Q.RE LODOVICO IL MORO           1
# SAN SIRO                                                 1
# SARPI                                                    2
# SCALO ROMANA                                             1
# STADERA - CHIESA ROSSA - Q.RE TORRETTA - CONCA ...       1
# STAZIONE CENTRALE - PONTE SEVESO                         1
# TIBALDI                                                  2
# UMBRIA - MOLISE - CALVAIRATE                             1
# VIGENTINO - Q.RE FATIMA                                  1
# VILLAPIZZONE - CAGNOLA - BOLDINASCO                      1
# XXII MARZO                                               2

# %% [markdown]
# **20. visualizzare il numero di uffici per ogni Nucleo di Identità Locale (NIL). Ordinare a partire dal NIL che ha più uffici in giù**

# %%
#df1.sort_values('UFFICI',  ascending=True)
df.groupby(df['NIL']).count()[['Indirizzo']].sort_values('Indirizzo',  ascending=False)
# In ordibbe decresente
# Out:
#                                                     Indirizzo
# NIL
# DUOMO                                                       7
# BRERA                                                       4
# BUENOS AIRES - PORTA VENEZIA - PORTA MONFORTE               4
# GIAMBELLINO                                                 3
# ISOLA                                                       3
# PADOVA - TURRO - CRESCENZAGO                                2
# NIGUARDA - CA' GRANDA - PRATO CENTENARO - Q.RE ...          2
# AFFORI                                                      2
# MACIACHINI - MAGGIOLINA                                     2
# LORETO - CASORETTO - NOLO                                   2
# Q.RE GALLARATESE - Q.RE SAN LEONARDO - LAMPUGNANO           2
# QUARTO OGGIARO - VIALBA - MUSOCCO                           2
# FORZE ARMATE                                                2
# XXII MARZO                                                  2
# TIBALDI                                                     2
# BAGGIO - Q.RE DEGLI OLMI - Q.RE VALSESIA                    2
# SARPI                                                       2
# SAN SIRO                                                    1
# PORTA TICINESE - CONCHETTA                                  1
# PORTA VIGENTINA - PORTA LODOVICA                            1
# VILLAPIZZONE - CAGNOLA - BOLDINASCO                         1
# VIGENTINO - Q.RE FATIMA                                     1
# PTA ROMANA                                                  1
# UMBRIA - MOLISE - CALVAIRATE                                1
# STAZIONE CENTRALE - PONTE SEVESO                            1
# QT 8                                                        1
# STADERA - CHIESA ROSSA - Q.RE TORRETTA - CONCA ...          1
# SCALO ROMANA                                                1
# QUINTO ROMANO                                               1
# ROGOREDO - SANTA GIULIA                                     1
# RONCHETTO SUL NAVIGLIO - Q.RE LODOVICO IL MORO              1
# PORTA MAGENTA                                               1
# PORTA TICINESE - CONCA DEL NAVIGLIO                         1
# ADRIANO                                                     1
# PORTA GENOVA                                                1
# PORTA GARIBALDI - PORTA NUOVA                               1
# BANDE NERE                                                  1
# BOVISASCA                                                   1
# BRUZZANO                                                    1
# CIMIANO - ROTTOLE - Q.RE FELTRE                             1
# CITTA' STUDI                                                1
# CORSICA                                                     1
# DE ANGELI - MONTE ROSA                                      1
# DERGANO                                                     1
# FARINI                                                      1
# GORLA - PRECOTTO                                            1
# GRATOSOGLIO - Q.RE MISSAGLIA - Q.RE TERRAZZE                1
# GRECO - SEGNANO                                             1
# GUASTALLA                                                   1
# LAMBRATE - ORTICA                                           1
# LODI - CORVETTO                                             1
# MONCUCCO - SAN CRISTOFORO                                   1
# PAGANO                                                      1
# MONLUE' - PONTE LAMBRO                                      1

# %%
df['NIL'].value_counts()
# Out:
# DUOMO                                                          7
# BUENOS AIRES - PORTA VENEZIA - PORTA MONFORTE                  4
# BRERA                                                          4
# GIAMBELLINO                                                    3
# ISOLA                                                          3
# QUARTO OGGIARO - VIALBA - MUSOCCO                              2
# MACIACHINI - MAGGIOLINA                                        2
# Q.RE GALLARATESE - Q.RE SAN LEONARDO - LAMPUGNANO              2
# NIGUARDA - CA' GRANDA - PRATO CENTENARO - Q.RE FULVIO TESTI    2
# BAGGIO - Q.RE DEGLI OLMI - Q.RE VALSESIA                       2
# PADOVA - TURRO - CRESCENZAGO                                   2
# FORZE ARMATE                                                   2
# TIBALDI                                                        2
# XXII MARZO                                                     2
# SARPI                                                          2
# LORETO - CASORETTO - NOLO                                      2
# AFFORI                                                         2
# ADRIANO                                                        1
# PORTA TICINESE - CONCA DEL NAVIGLIO                            1
# DERGANO                                                        1
# GORLA - PRECOTTO                                               1
# QT 8                                                           1
# STAZIONE CENTRALE - PONTE SEVESO                               1
# ROGOREDO - SANTA GIULIA                                        1
# VILLAPIZZONE - CAGNOLA - BOLDINASCO                            1
# CITTA' STUDI                                                   1
# CORSICA                                                        1
# PORTA TICINESE - CONCHETTA                                     1
# STADERA - CHIESA ROSSA - Q.RE TORRETTA - CONCA FALLATA         1
# BRUZZANO                                                       1
# CIMIANO - ROTTOLE - Q.RE FELTRE                                1
# SAN SIRO                                                       1
# PTA ROMANA                                                     1
# PAGANO                                                         1
# QUINTO ROMANO                                                  1
# LAMBRATE - ORTICA                                              1
# FARINI                                                         1
# PORTA VIGENTINA - PORTA LODOVICA                               1
# GRECO - SEGNANO                                                1
# DE ANGELI - MONTE ROSA                                         1
# MONLUE' - PONTE LAMBRO                                         1
# VIGENTINO - Q.RE FATIMA                                        1
# MONCUCCO - SAN CRISTOFORO                                      1
# PORTA GENOVA                                                   1
# GRATOSOGLIO - Q.RE MISSAGLIA - Q.RE TERRAZZE                   1
# GUASTALLA                                                      1
# PORTA MAGENTA                                                  1
# BANDE NERE                                                     1
# RONCHETTO SUL NAVIGLIO - Q.RE LODOVICO IL MORO                 1
# UMBRIA - MOLISE - CALVAIRATE                                   1
# SCALO ROMANA                                                   1
# BOVISASCA                                                      1
# PORTA GARIBALDI - PORTA NUOVA                                  1
# LODI - CORVETTO                                                1
# Name: NIL, dtype: int64

# %% [markdown]
# **21. visualizzare i municipi che hanno più di 15 uffici postali**

# %%
df['MUNICIPIO'].value_counts()[df['MUNICIPIO'].value_counts() > 10]
# Out:
# 1    14
# 9    13
# Name: MUNICIPIO, dtype: int64

# %%
df.groupby(df['MUNICIPIO']).count()[['Location']]
# Ma qua non ci sono
# Out:
#            Location
# MUNICIPIO
# 1                14
# 2                 9
# 3                 7
# 4                 7
# 5                 7
# 6                 8
# 7                 8
# 8                 9
# 9                13

# %% [markdown]
# **22. visualizzare il municipio che ha più uffici postali**

# %%
df.groupby("MUNICIPIO")["Location"].count().idxmax()
#df['MUNICIPIO'].value_counts().idxmax()
# Out:
# 1

# %% [markdown]
# **23. visualizzare il municipio che ha meno uffici postali**

# %%
#df.groupby("MUNICIPIO")["Indirizzo"].count().idxmin()
#df["MUNICIPIO"].value_counts().idxmin()
df.MUNICIPIO.value_counts()[df.MUNICIPIO.value_counts() == df.MUNICIPIO.value_counts().min()]
#df["MUNICIPIO"].value_counts()[df["MUNICIPIO"].value_counts() == df["MUNICIPIO"].value_counts().min()]
# Out:
# 5    7
# 4    7
# 3    7
# Name: MUNICIPIO, dtype: int64

# %% [markdown]
# **24. visualizzare il numero medio di uffici postali in ogni municipio**

# %%
#df.groupby(df['MUNICIPIO']).count().mean().round(2)
#df.groupby("MUNICIPIO")["Indirizzo"].count().mean()
df["MUNICIPIO"].value_counts().mean()
# Out:
# 9.11111111111111

# %% [markdown]
# **25. visualizzare gli uffici postali che hanno un numero di uffici postali superiore alla media**

# %%
df.groupby("MUNICIPIO")["Indirizzo"].count().mean() < df.groupby(df['MUNICIPIO']).count()[['Location']]
# Out:
#            Location
# MUNICIPIO
# 1              True
# 2             False
# 3             False
# 4             False
# 5             False
# 6             False
# 7             False
# 8             False
# 9              True

# %%
df5 = df.groupby("MUNICIPIO").count()
#df5.mean()
df5[df5.Indirizzo > df5.Indirizzo.mean()]
# Out:
#            Indirizzo  Telefono  Fax  ...  LONG_X_4326  LAT_Y_4326  Location
# MUNICIPIO                            ...
# 1                 14        13   13  ...           14          14        14
# 9                 13        12   12  ...           13          13        13
#
# [2 rows x 9 columns]

# %% [markdown]
# # **Eliminazione di righe o colonne**

# %% [markdown]
# **26. eliminare tutti i record relativi al NIL di Niguarda**

# %%
#df[df['NIL'].str.contains("NIGUARDA")]
df1 = df[~df.NIL.str.contains("NIGUARDA")]
df1

# %%
df = df.drop(df[df['NIL'].str.contains("NIGUARDA")].index)
df
# Out:
#                       Indirizzo  ...                                Location
# 0     BASTIONI DI PORTA VOLTA 7  ...   (45.47960100000006;9.182151000000033)
# 1   CORSO DI PORTA VIGENTINA 35  ...   (45.45253800000006;9.196519500000022)
# 2                CORSO ITALI 16  ...   (45.45789300000007;9.187470000000076)
# 3             CORSO SEMPIONE 94  ...    (45.48654000000005;9.15850800000004)
# 4              CORSO VENEZIA 42  ...   (45.47186100000005;9.202702500000044)
# ..                          ...  ...                                     ...
# 77              VIALE GORIZIA 6  ...  (45.454518000000064;9.173155500000064)
# 78       VIALE MONTE CENERI SNC  ...   (45.49156751800007;9.153591732000052)
# 79          VIALE SABOTINO 21/A  ...  (45.451017000000036;9.200173500000062)
# 80       VIALE SAN GIMIGNANO 10  ...  (45.455868000000066;9.136525500000062)
# 81               VIALE ZARA 131  ...   (45.50019300000008;9.196686000000057)
#
# [80 rows x 10 columns]

# %% [markdown]
# **27. eliminare le ultime tre colonne**

# %%
df.drop(df.tail(3).index,inplace=True)
df
#df = df[:-3]
#df
#
# Out:
#                       Indirizzo  ...                                Location
# 0     BASTIONI DI PORTA VOLTA 7  ...   (45.47960100000006;9.182151000000033)
# 1   CORSO DI PORTA VIGENTINA 35  ...   (45.45253800000006;9.196519500000022)
# 2                CORSO ITALI 16  ...   (45.45789300000007;9.187470000000076)
# 3             CORSO SEMPIONE 94  ...    (45.48654000000005;9.15850800000004)
# 4              CORSO VENEZIA 42  ...   (45.47186100000005;9.202702500000044)
# ..                          ...  ...                                     ...
# 74           VIALE CASSIODORO 4  ...   (45.47363400000006;9.160069500000077)
# 75    VIALE EVARISTO STEFINI 12  ...  (45.496440000000064;9.202455000000043)
# 76       VIALE GIOVANNI SUZZANI  ...   (45.52444928500006;9.207933420000074)
# 77              VIALE GORIZIA 6  ...  (45.454518000000064;9.173155500000064)
# 78       VIALE MONTE CENERI SNC  ...   (45.49156751800007;9.153591732000052)
#
# [79 rows x 10 columns]

# %% [markdown]
# **28. eliminare i record di cui non si conosce il numero di telefono o il fax**

# %%
df.dropna(subset = ["Telefono","Fax"], inplace=True)
df
# Out:
#                                Indirizzo  ...                                Location
# 0              BASTIONI DI PORTA VOLTA 7  ...   (45.47960100000006;9.182151000000033)
# 1            CORSO DI PORTA VIGENTINA 35  ...   (45.45253800000006;9.196519500000022)
# 2                         CORSO ITALI 16  ...   (45.45789300000007;9.187470000000076)
# 4                       CORSO VENEZIA 42  ...   (45.47186100000005;9.202702500000044)
# 5   LARGO GIOVANNI BATTISTA SCALABRINI 5  ...    (45.45039600000007;9.14118300000007)
# ..                                   ...  ...                                     ...
# 74                    VIALE CASSIODORO 4  ...   (45.47363400000006;9.160069500000077)
# 75             VIALE EVARISTO STEFINI 12  ...  (45.496440000000064;9.202455000000043)
# 76                VIALE GIOVANNI SUZZANI  ...   (45.52444928500006;9.207933420000074)
# 77                       VIALE GORIZIA 6  ...  (45.454518000000064;9.173155500000064)
# 78                VIALE MONTE CENERI SNC  ...   (45.49156751800007;9.153591732000052)
#
# [74 rows x 10 columns]

# %% [markdown]
# # **Aggiornamento di informazioni**

# %% [markdown]
# **29. modificare il numero di telefono dell'ufficio di viale Zara in 02-69922222**

# %%
df= pd.read_csv('https://raw.githubusercontent.com/CappuCitti/Python-appunti-ed-esercizi/main/Pandas/Data/uffici_postali_milano.csv')
df

# %%
df6 = df.copy()
'''df6 = df6.set_index('Indirizzo')
df6.loc['VIALE ZARA 131','Telefono'] = "02-69922222"'''
#df6.loc[-1:,'Telefono'] = "02-69922222"
#df6.iloc[-1 ,1] = "02-69922222"
#df6
# Out:
# 'df6 = df6.set_index(\'Indirizzo\')\ndf6.loc[\'VIALE ZARA 131\',\'Telefono\'] = "02-69922222"'

# %%
#df6[df6.Indirizzo.str.contains('VIALE ZARA')][['Telefono']] = "02-69922222"
#df6 NON FUNZIONA

# %% [markdown]
# **30. sostituire il trattino presente nei numeri di telefono con il carattere /**

# %%
df['Telefono'] = df['Telefono'].str.replace('-','/')
df
# Out:
#                       Indirizzo  ...                                Location
# 0     BASTIONI DI PORTA VOLTA 7  ...   (45.47960100000006;9.182151000000033)
# 1   CORSO DI PORTA VIGENTINA 35  ...   (45.45253800000006;9.196519500000022)
# 2                CORSO ITALI 16  ...   (45.45789300000007;9.187470000000076)
# 3             CORSO SEMPIONE 94  ...    (45.48654000000005;9.15850800000004)
# 4              CORSO VENEZIA 42  ...   (45.47186100000005;9.202702500000044)
# ..                          ...  ...                                     ...
# 77              VIALE GORIZIA 6  ...  (45.454518000000064;9.173155500000064)
# 78       VIALE MONTE CENERI SNC  ...   (45.49156751800007;9.153591732000052)
# 79          VIALE SABOTINO 21/A  ...  (45.451017000000036;9.200173500000062)
# 80       VIALE SAN GIMIGNANO 10  ...  (45.455868000000066;9.136525500000062)
# 81               VIALE ZARA 131  ...   (45.50019300000008;9.196686000000057)
#
# [82 rows x 10 columns]

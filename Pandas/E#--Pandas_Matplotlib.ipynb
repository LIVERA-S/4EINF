# %% [markdown]
# <a href="https://colab.research.google.com/github/LIVERA-S/21-22_INFORMATICA_LIVERA-4EINF/blob/main/E%23--Pandas_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pymongo
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# **1. caricare i dati in un dataframe**

# %%
'''client = pymongo.MongoClient("mongodb://Livera2003:Waduge78&@cluster0-shard-00-00.uylmr.mongodb.net:27017,cluster0-shard-00-01.uylmr.mongodb.net:27017,cluster0-shard-00-02.uylmr.mongodb.net:27017/myFirstDatabase?ssl=true&replicaSet=atlas-38dmxu-shard-0&authSource=admin&retryWrites=true&w=majority")
db = client.Livera1 # nome del database'''
# Out:
# 'client = pymongo.MongoClient("mongodb://Livera2003:Waduge78&@cluster0-shard-00-00.uylmr.mongodb.net:27017,cluster0-shard-00-01.uylmr.mongodb.net:27017,cluster0-shard-00-02.uylmr.mongodb.net:27017/myFirstDatabase?ssl=true&replicaSet=atlas-38dmxu-shard-0&authSource=admin&retryWrites=true&w=majority")\ndb = client.Livera1 # nome del database'

# %% [markdown]
# **2. visualizzare i dati**

# %%
'''import pandas as pd
df = pd.DataFrame.from_records(db.prime.find())
df'''
df= pd.read_csv('https://raw.githubusercontent.com/wtitze/4E/main/prime_titles.csv')
df
# Out:
#      S.no.           Name of the show  ...  IMDb rating  Age of viewers
# 0        1                 Pataal Lok  ...          7.5             18+
# 1        2                     Upload  ...          8.1             16+
# 2        3  The Marvelous Mrs. Maisel  ...          8.7             16+
# 3        4     Four More Shots Please  ...          5.3             18+
# 4        5                    Fleabag  ...          8.7             18+
# ..     ...                        ...  ...          ...             ...
# 399    400                        NaN  ...          NaN             NaN
# 400    401                        NaN  ...          NaN             NaN
# 401    402                        NaN  ...          NaN             NaN
# 402    403                        NaN  ...          NaN             NaN
# 403    404                        NaN  ...          NaN             NaN
#
# [404 rows x 8 columns]

# %% [markdown]
# **3. eliminare dal dataframe tutti i record con valori NaN**

# %%
df.dropna(inplace=True)
df
# Out:
#      S.no.                       Name of the show  ...  IMDb rating  Age of viewers
# 0        1                             Pataal Lok  ...          7.5             18+
# 1        2                                 Upload  ...          8.1             16+
# 2        3              The Marvelous Mrs. Maisel  ...          8.7             16+
# 3        4                 Four More Shots Please  ...          5.3             18+
# 4        5                                Fleabag  ...          8.7             18+
# ..     ...                                    ...  ...          ...             ...
# 373    374                  The Danny Thomas Show  ...          7.2             All
# 374    375  Hitoshi Matsumoto Presents Documental  ...          8.0             18+
# 375    376                  Businessmen VS Aliens  ...          4.5             13+
# 379    380                  Scooter: Secret Agent  ...          6.8             All
# ...

# %% [markdown]
# **4. calcolare il numero di show per ogni lingua. Ordinare in ordine decrescente sul numero**

# %%
'''df1 = df.copy()
df1 = df1.groupby(['area']).count()[["nome"]].reset_index().rename(columns={"nome":"totale"}).set_index('area')'''
# Out:
# 'df1 = df.copy()\ndf1 = df1.groupby([\'area\']).count()[["nome"]].reset_index().rename(columns={"nome":"totale"}).set_index(\'area\')'

# %%
df.groupby('Language').count()[['Name of the show']].rename(columns={"Name of the show":"totale"})
# Out:
#           totale
# Language
# Deutsch        1
# English      155
# Hindi         17
# Japanese       7
# Spanish        1
# Suomi          1

# %%
df['Language'].value_counts()
# Out:
# English     155
# Hindi        17
# Japanese      7
# Suomi         1
# Deutsch       1
# Spanish       1
# Name: Language, dtype: int64

# %% [markdown]
# **5. visualizzare il grafico a barre verticali dei dati precedenti**

# %%
df1 = df['Language'].value_counts()
fig, ax = plt.subplots()
fig.set_figwidth(12)
fig.set_figheight(8)
fig.autofmt_xdate(rotation=90)
ax.bar(df1.index,df1)
# Out:
# <BarContainer object of 6 artists>

# %% [markdown]
# **6. visualizzare le stesse informazioni dell'esercizio precedente utilizzando un grafico a torta**

# %%
'''labelspie = list(df2.index)
sizes = list(df2['cuisine'])
fig1, ax1 = plt.subplots(figsize=(10, 10))
ax1.pie(sizes, labels=labelspie, autopct='%1.1f%%',textprops={'fontsize': 14}, startangle= 90)
plt.show()'''
# Out:
# "labelspie = list(df2.index)\nsizes = list(df2['cuisine'])\nfig1, ax1 = plt.subplots(figsize=(10, 10))\nax1.pie(sizes, labels=labelspie, autopct='%1.1f%%',textprops={'fontsize': 14}, startangle= 90)\nplt.show()"

# %%
df2 = df['Language'].value_counts()
df2

fig1, ax1 = plt.subplots(figsize=(10, 10))
ax1.pie(df2, labels=df2.index, autopct='%1.1f%%',textprops={'fontsize': 14}, startangle= 90)
plt.show()

# %% [markdown]
# **7. creare un nuovo dataframe che nella colonna 'Language' contenga solo 'English' o 'non English'**

# %%
df3 = df.copy()
df3['Language'][df3['Language']!='English'] = 'non English'
df3
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      S.no.                       Name of the show  ...  IMDb rating  Age of viewers
# 0        1                             Pataal Lok  ...          7.5             18+
# 1        2                                 Upload  ...          8.1             16+
# 2        3              The Marvelous Mrs. Maisel  ...          8.7             16+
# 3        4                 Four More Shots Please  ...          5.3             18+
# 4        5                                Fleabag  ...          8.7             18+
# ..     ...                                    ...  ...          ...             ...
# 373    374                  The Danny Thomas Show  ...          7.2             All
# ...

# %%
df3.groupby(['Year of release','Language']).count()
# Out:
#                              S.no.  ...  Age of viewers
# Year of release Language            ...
# 1958.0          English          2  ...               2
# 1967.0          English          1  ...               1
# 1985.0          English          1  ...               1
# 1988.0          English          1  ...               1
# 1990.0          English          1  ...               1
# 1995.0          English          1  ...               1
# 1998.0          English          1  ...               1
#                 non English      1  ...               1
# 1999.0          English          1  ...               1
# 2003.0          English          2  ...               2
# 2004.0          English          1  ...               1
# 2005.0          English          1  ...               1
# 2006.0          English          2  ...               2
# 2007.0          English          4  ...               4
# 2009.0          English          2  ...               2
# ...

# %%
df5 = df3.groupby(['Year of release','Language']).count()['S.no.'].unstack().reset_index().tail(10)
df5
# Out:
# Language  Year of release  English  non English
# 15                 2011.0      4.0          NaN
# 16                 2012.0      6.0          NaN
# 17                 2013.0      4.0          NaN
# 18                 2014.0      9.0          1.0
# 19                 2015.0     12.0          3.0
# 20                 2016.0     28.0          2.0
# 21                 2017.0     23.0          1.0
# 22                 2018.0     12.0          8.0
# 23                 2019.0     15.0          9.0
# 24                 2020.0     15.0          2.0

# %% [markdown]
# **8. visualizzare un grafico a barre con gli anni sulle ascisse e il numero di show in inglese e non in inglese sulle ordinate. Considerare solo gli ultimi 10 anni (vedi grafico allegato come esempio)**

# %%
labels = df5['Year of release']
men_means = df5.English
women_means = df5['non English']

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=(15,8))
rects1 = ax.bar(x - width/2, men_means, width, label='American')
rects2 = ax.bar(x + width/2, women_means, width, label='non American')

fig.autofmt_xdate(rotation=90)                             # Ruota i nomi dei valori sulle ascisse di 45 gradi
fig.suptitle('Tipologia di cucina')    # Imposta il titolo del grafico
fig.legend(loc=1)                                          # Crea la legenda e la posiziona nel I quadrante

ax.set_xticks(x)              # Seleziona ogni quanto visualizzare un nome sulle ascisse
ax.set_xticklabels(labels) 
plt.show()

# %% [markdown]
# A partire dal notebook Python presente nel post della verifica, scrivere le istruzioni per collegarsi al
# database sample_mflix.
#
# e per estrarre, dalla collection movies , le informazioni seguenti. Inserire nel notebook la richiesta
# (sottoforma di markdown) e il codice necessario per risolverla. Indentare il codice in modo che sia il più
# chiaro possibile. Se non indicato esplicitamente, estrarre tutti i campi della collection.
# Informazioni da reperire

# %%
import pymongo
import pandas as pd

# %%
client = pymongo.MongoClient("mongodb://webUser:xxx123xxx@cluster0-shard-00-00.algwo.mongodb.net:27017,cluster0-shard-00-01.algwo.mongodb.net:27017,cluster0-shard-00-02.algwo.mongodb.net:27017/?ssl=true&replicaSet=atlas-am4cb3-shard-0&authSource=admin&retryWrites=true&w=majority")
db = client.sample_mflix # nome del database

# %%
doc = db.movies.find_one()
doc
# Out:
# {'_id': ObjectId('573a1391f29313caabcd68d0'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Harold Lloyd',
#   'Mildred Davis',
#   "'Snub' Pollard",
#   'Peggy Cartwright'],
#  'countries': ['USA'],
#  'directors': ['Alfred J. Goulding', 'Hal Roach'],
#  'fullplot': "As a penniless man worries about how he will manage to eat, he is joined by a young waif and her dog, who are in the same predicament. Meanwhile, across town a dishonest lawyer is working with a gang of criminals, trying to swindle an innocent young heiress out of her inheritance. As the heiress is on her way home from the lawyer's office, she notices the young man and the waif in the midst of their latest problem with the authorities, and she rescues them. Later on, the young man will have an unexpected opportunity to repay her for her kindness.",
#  'genres': ['Comedy', 'Short', 'Action'],
#  'imdb': {'id': 10146, 'rating': 7.0, 'votes': 639},
#  'languages': ['English'],
#  'lastupdated': '2015-04-17 00:16:14.220000000',
#  'plot': 'A penniless young man tries to save an heiress from kidnappers and help her secure her inheritance.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNzE1OWRlNDgtMTllNi00NTZiLWIyNTktYTk0MDY1ZWUwYTc5XkEyXkFqcGdeQXVyMjUxODE0MDY@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'TV-G',
#  'released': datetime.datetime(1919, 12, 28, 0, 0),
#  'runtime': 22,
#  'title': 'From Hand to Mouth',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 8, 21, 18, 45, 11),
#   'production': 'Pathè Exchange',
#   'viewer': {'meter': 55, 'numReviews': 71, 'rating': 3.3}},
#  'type': 'movie',
#  'writers': ['H.M. Walker (titles)'],
#  'year': 1919}

# %%
df1 = pd.DataFrame(list(db.movies.find()))
df1.head()
# Out:
#                         _id  \
# 0  573a1391f29313caabcd68d0
# 1  573a1391f29313caabcd6ea2
# 2  573a1391f29313caabcd6d90
# 3  573a1390f29313caabcd4eaf
# 4  573a1390f29313caabcd5ea4
#
#                                                 plot                   genres  \
# 0  A penniless young man tries to save an heiress...  [Comedy, Short, Action]
# 1  The simple-minded son of a rich financier must...                 [Comedy]
# 2  As Alice and Cora Munro attempt to find their ...       [Adventure, Drama]
# 3  A woman, with the aid of her police officer sw...           [Crime, Drama]
# 4  A District Attorney's outspoken stand on abort...                  [Drama]
#
#    runtime      rated                                               cast  \
# 0     22.0       TV-G  [Harold Lloyd, Mildred Davis, 'Snub' Pollard, ...
# 1     77.0        NaN  [Edward Jobson, Beulah Booker, Edward Connelly...
# 2     73.0  NOT RATED  [Wallace Beery, Barbara Bedford, Alan Roscoe, ...
# 3     88.0      TV-PG  [Jane Gail, Ethel Grandin, William H. Turner, ...
# 4     62.0   APPROVED  [Tyrone Power Sr., Helen Riaume, Marie Walcamp...
#
#                                               poster  \
# 0  https://m.media-amazon.com/images/M/MV5BNzE1OW...
# 1  https://m.media-amazon.com/images/M/MV5BZDNiOD...
# 2  https://m.media-amazon.com/images/M/MV5BZmJkZD...
# 3  https://m.media-amazon.com/images/M/MV5BYzk0YW...
# 4                                                NaN
#
#                       title  \
# 0        From Hand to Mouth
# 1               The Saphead
# 2  The Last of the Mohicans
# 3          Traffic in Souls
# 4    Where Are My Children?
#
#                                             fullplot  languages  ...  \
# 0  As a penniless man worries about how he will m...  [English]  ...
# 1  Nick Van Alstyne owns the Henrietta silver min...        NaN  ...
# 2  As Alice and Cora Munro attempt to find their ...  [English]  ...
# 3                                                NaN  [English]  ...
# 4  While prosecuting a physician for the death of...  [English]  ...
#
#                                              writers  \
# 0                             [H.M. Walker (titles)]
# 1  [Bronson Howard (original play "The Henrietta"...
# 2  [James Fenimore Cooper (novel), Robert Dillon ...
# 3                                                NaN
# 4  [Lucy Payton (from the story by), Franklin Hal...
#
#                                               awards  \
# 0  {'wins': 0, 'nominations': 1, 'text': '1 nomin...
# 1  {'wins': 0, 'nominations': 1, 'text': '1 nomin...
# 2    {'wins': 1, 'nominations': 0, 'text': '1 win.'}
# 3    {'wins': 1, 'nominations': 0, 'text': '1 win.'}
# 4    {'wins': 1, 'nominations': 0, 'text': '1 win.'}
#
#                      lastupdated  year  \
# 0  2015-04-17 00:16:14.220000000  1919
# 1  2015-06-20 00:38:08.303000000  1920
# 2  2015-07-19 00:12:27.010000000  1920
# 3  2015-09-15 02:07:14.247000000  1913
# 4  2015-09-07 00:51:32.560000000  1916
#
#                                           imdb countries   type  \
# 0   {'rating': 7.0, 'votes': 639, 'id': 10146}     [USA]  movie
# 1  {'rating': 6.2, 'votes': 1020, 'id': 11652}     [USA]  movie
# 2   {'rating': 6.9, 'votes': 773, 'id': 11387}     [USA]  movie
# 3    {'rating': 6.0, 'votes': 371, 'id': 3471}     [USA]  movie
# 4    {'rating': 5.9, 'votes': 247, 'id': 7558}     [USA]  movie
#
#                                             tomatoes num_mflix_comments  \
# 0  {'viewer': {'rating': 3.3, 'numReviews': 71, '...                NaN
# 1  {'viewer': {'rating': 3.3, 'numReviews': 435, ...                2.0
# 2  {'viewer': {'rating': 3.5, 'numReviews': 306, ...                NaN
# 3  {'viewer': {'rating': 3.0, 'numReviews': 85, '...                2.0
# 4  {'viewer': {'rating': 3.1, 'numReviews': 34, '...                NaN
#
#   metacritic
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#
# [5 rows x 22 columns]
# Warning: Total number of columns (22) exceeds max_columns (20) limiting to first (20) columns.

# %% [markdown]
# 1. Gli attori dei film

# %%
result=db.movies.find({},{"cast":1,"_id":0})
df = pd.DataFrame(list(result))
df
# Out:
#                                                     cast
# 0      [Harold Lloyd, Mildred Davis, 'Snub' Pollard, ...
# 1      [Edward Jobson, Beulah Booker, Edward Connelly...
# 2      [Wallace Beery, Barbara Bedford, Alan Roscoe, ...
# 3      [Jane Gail, Ethel Grandin, William H. Turner, ...
# 4      [Tyrone Power Sr., Helen Riaume, Marie Walcamp...
# ...                                                  ...
# 23525  [Richa Chadda, Sanjay Mishra, Vicky Kaushal, V...
# 23526                                  [Chantal Akerman]
# 23527  [Holly Aird, Eileen Atkins, Hugh Bonneville, T...
# 23528  [Toni Rakkaen, Ingkarat Damrongsakkul, Thira C...
# 23529  [Aharon Traitel, Khalifa Natour, Riki Blich, G...
#
# [23530 rows x 1 columns]

# %%
result = db.movies.aggregate([{"$unwind":"$cast"},
                              {"$group": {"_id":"$cast"}},
                              {"$sort":{"cast":-1}}])
df2 = pd.DataFrame(list(result))
df2
# Out:
#                        _id
# 0           Layke Anderson
# 1         Deborah Ann Woll
# 2      Nicollette Sheridan
# 3              Moe Dunford
# 4            Henry Bergman
# ...                    ...
# 42145    Mitsutaka Itakura
# 42146        Nikita Tyunin
# 42147          Ward Luarca
# 42148        Soufia Issami
# 42149         Yèrei Yanagi
#
# [42150 rows x 1 columns]

# %% [markdown]
# 2. Gli attori il cui nome comincia per A

# %%
result = db.movies.aggregate([{"$unwind":"$cast"},
                              {"$match":{"cast":{"$regex":"^A.*"}}},
                              {"$group": {"_id":"$cast"}}])
df2 = pd.DataFrame(list(result))
df2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bb03fd42ada3> in <module>()
# ----> 1 result = db.movies.aggregate([{"$unwind":"$cast"},
#       2                               {"$match":{"cast":{"$regex":"^A.*"}}},
#       3                               {"$group": {"_id":"$cast"}}])
#       4 df2 = pd.DataFrame(list(result))
#       5 df2
#
# NameError: name 'db' is not defined

# %% [markdown]
# 3. Gli attori che hanno recitato in film americani

# %%
result = db.movies.aggregate([{"$unwind":"$cast"},
                              {"$match":{"countries":"USA"}},
                              {"$project":{"_id":0,"cast":1}}])
df2 = pd.DataFrame(list(result))
df2
# Out:
#                          cast
# 0                Harold Lloyd
# 1               Mildred Davis
# 2              'Snub' Pollard
# 3            Peggy Cartwright
# 4               Edward Jobson
# ...                       ...
# 45926    Sarah Ellen Stephens
# 45927            Toni Rakkaen
# 45928  Ingkarat Damrongsakkul
# 45929          Thira Chutikul
# 45930          Arthur Navarat
#
# [45931 rows x 1 columns]

# %% [markdown]
# 4. Gli attori che hanno recitato in film italiani e francesi

# %%
result = db.movies.aggregate([{"$unwind":"$cast"},
                              {"$match":{'$or':[{'countries':"Italy"},{'countries':"France"}]}},
                              {"$project":{"_id":0,"cast":1}}])
df2 = pd.DataFrame(list(result))
df2
# Out:
#                      cast
# 0          Albert Prèjean
# 1             Pola Illèry
# 2      Edmond T. Grèville
# 3             Bill Bocket
# 4       Alexander Granach
# ...                   ...
# 15107        Richa Chadda
# 15108       Sanjay Mishra
# 15109       Vicky Kaushal
# 15110         Vinit Kumar
# 15111     Chantal Akerman
#
# [15112 rows x 1 columns]

# %% [markdown]
# 5. I film in cui hanno recitato Margaret Singer e Sarah Ellen Stephens

# %%
result = db.movies.aggregate([{"$unwind":"$cast"},
                              {"$match": {'$or': [{"cast" : "Margaret Singer"} , {"cast" : "Sarah Ellen Stephens"}]}}])
df2 = pd.DataFrame(list(result))
df2
# Out:
#                         _id countries                   genres  runtime  \
# 0  573a13f8f29313caabde9156     [USA]  [Short, Drama, Romance]       14
# 1  573a13f8f29313caabde9156     [USA]  [Short, Drama, Romance]       14
#
#                    cast    title                    lastupdated  languages  \
# 0       Margaret Singer  Hallway  2015-05-21 21:15:39.987000000  [English]
# 1  Sarah Ellen Stephens  Hallway  2015-05-21 21:15:39.987000000  [English]
#
#     released     directors       writers  \
# 0 2015-03-14  [Leah Shore]  [Leah Shore]
# 1 2015-03-14  [Leah Shore]  [Leah Shore]
#
#                                               awards  year  \
# 0  {'wins': 0, 'nominations': 1, 'text': '1 nomin...  2015
# 1  {'wins': 0, 'nominations': 1, 'text': '1 nomin...  2015
#
#                                          imdb   type
# 0  {'rating': '', 'votes': '', 'id': 4522158}  movie
# 1  {'rating': '', 'votes': '', 'id': 4522158}  movie

# %%
result = db.movies.aggregate([{"$match": {"cast" : ["Margaret Singer","Sarah Ellen Stephens"]}}])
df2 = pd.DataFrame(list(result))
df2
# Out:
#                         _id countries                   genres  runtime  \
# 0  573a13f8f29313caabde9156     [USA]  [Short, Drama, Romance]       14
#
#                                       cast    title  \
# 0  [Margaret Singer, Sarah Ellen Stephens]  Hallway
#
#                      lastupdated  languages   released     directors  \
# 0  2015-05-21 21:15:39.987000000  [English] 2015-03-14  [Leah Shore]
#
#         writers                                             awards  year  \
# 0  [Leah Shore]  {'wins': 0, 'nominations': 1, 'text': '1 nomin...  2015
#
#                                          imdb   type
# 0  {'rating': '', 'votes': '', 'id': 4522158}  movie

# %% [markdown]
# 6. I film che non hanno la valutazione di metacritic

# %% [markdown]
# 7. Il numero di film per ogni attore. Ordinare in ordine decrescente a
# partire dall’attore che ha recitato di più

# %% [markdown]
# 8. I primi 10 attori della lista precedente

# %% [markdown]
# 9. Gli attori che hanno recitato in un numero di film compreso tra 1° e 20

# %% [markdown]
# 10. Il numero medio di film in cui ha recitato un attore

# %% [markdown]
# 11. I film che hanno un a valutazione di metacritic superiore alla media

# %% [markdown]
# 12. Il film con più attori

# %%
result = db.movies.aggregate([{ "$unwind": "$cast" },
                              { "$group" : {"_id": "$cast", "total" : {"$sum" : 1}}},
                              { "$sort": {"total": -1 }},
                              { "$project": {"_id": 0,"title":1,"Attori": "$_id","total": "$total"}}])
df2 = pd.DataFrame(list(result))
df2
# Out:
#                      Attori  total
# 0          Gèrard Depardieu     68
# 1            Robert De Niro     60
# 2             Michael Caine     52
# 3      Marcello Mastroianni     50
# 4             Max von Sydow     49
# ...                     ...    ...
# 42145        Gordon Jackson      1
# 42146           Shelby Knox      1
# 42147            Fred Brown      1
# 42148               Ding Li      1
# 42149      Florentine Lahme      1
#
# [42150 rows x 2 columns]

# %%
result=db.movies.aggregate([{"$unwind": "$cast"},
                            {"$group": {"_id" : "$title", "total" : {"$sum" : 1}}},
                            {"$sort": { "total": -1 }}
                          ])
df=pd.DataFrame(list(result))
df
# Out:
#                                        _id  total
# 0                                 The Hole     24
# 1                                   Hamlet     24
# 2                                Jane Eyre     24
# 3                            The Terrorist     24
# 4                              The Journey     23
# ...                                    ...    ...
# 21282                             One Life      1
# 21283  George Lopez: It's Not Me, It's You      1
# 21284                           Mount Head      1
# 21285                             Freeheld      1
# 21286   George Carlin: Jammin' in New York      1
#
# [21287 rows x 2 columns]
